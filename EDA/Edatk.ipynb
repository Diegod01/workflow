# %%
pip install edatk
# Out:
# Collecting edatk
#   Downloading edatk-0.0.6-py3-none-any.whl (32 kB)
# Collecting numpy>=1.20
#   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 8.1 MB/s
# Collecting matplotlib>=3.4.2
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 57.1 MB/s
# Requirement already satisfied: seaborn>=0.11 in /usr/local/lib/python3.7/dist-packages (from edatk) (0.11.2)
# Collecting jinja2>=3.0.1
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 63.0 MB/s
# Collecting scipy>=1.6.3
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# Collecting pandas>=1.2.4
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 24.8 MB/s
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from jinja2>=3.0.1->edatk) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.2->edatk) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.2->edatk) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.2->edatk) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.2->edatk) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.2->edatk) (7.1.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.28.5-py3-none-any.whl (890 kB)
#      |████████████████████████████████| 890 kB 39.8 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.2->edatk) (21.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.4->edatk) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.2->edatk) (1.15.0)
# Installing collected packages: numpy, fonttools, scipy, pandas, matplotlib, jinja2, edatk
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.5 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.5 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.0.3 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed edatk-0.0.6 fonttools-4.28.5 jinja2-3.0.3 matplotlib-3.5.1 numpy-1.21.5 pandas-1.3.5 scipy-1.7.3

# %%
import edatk as eda

# Load in your dataframe (using seaborn below as an example)
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/supermarket_sales - Sheet1.csv')

# %%
eda.auto_eda(df)
# Out:
# ========== Invoice ID ==========
# Column Name         : Invoice ID
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 1000
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# Invoice ID was not able to be profiled due to errors
#
#
# ========== Branch ==========
# Column Name         : Branch
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 3
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# Branch was not able to be profiled due to errors
#
#
# ========== City ==========
# Column Name         : City
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 3
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# City was not able to be profiled due to errors
#
#
# ========== Customer type ==========
# Column Name         : Customer type
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 2
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# Customer type was not able to be profiled due to errors
#
#
# ========== Gender ==========
# Column Name         : Gender
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 2
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# Gender was not able to be profiled due to errors
#
#
# ========== Product line ==========
# Column Name         : Product line
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 6
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# Product line was not able to be profiled due to errors
#
#
# ========== Unit price ==========
# Column Name         : Unit price
# Data Type Grouping  : numeric
# Data Type           : float64
# Row Count           : 1000
# Distinct Count      : 943
# Missing Values      : 0
# Missing Value %     : 0.00%
# Mean                : 55.67
# Median              : 55.23
# Min                 : 10.08
# Max                 : 99.96
# Standard Deviation  : 26.48
# CV %                : 47.57%
# Skew                : 0.01
# Kurtosis            : -1.22
# Text Box Plot       : |10.08 --||32.88 ~ 55.23 ~ 77.94||-- 99.96|
#
# Unit price was not able to be profiled due to errors
#
#
# ========== Quantity ==========
# Column Name         : Quantity
# Data Type Grouping  : numeric-condensed
# Data Type           : int64
# Row Count           : 1000
# Distinct Count      : 10
# Missing Values      : 0
# Missing Value %     : 0.00%
# Mean                : 5.51
# Median              : 5.00
# Min                 : 1
# Max                 : 10
# Standard Deviation  : 2.92
# CV %                : 53.03%
# Skew                : 0.01
# Kurtosis            : -1.22
# Text Box Plot       : |1.00 --||3.00 ~ 5.00 ~ 8.00||-- 10.00|
#
# Quantity was not able to be profiled due to errors
#
#
# ========== Tax 5% ==========
# Column Name         : Tax 5%
# Data Type Grouping  : numeric
# Data Type           : float64
# Row Count           : 1000
# Distinct Count      : 990
# Missing Values      : 0
# Missing Value %     : 0.00%
# Mean                : 15.38
# Median              : 12.09
# Min                 : 0.51
# Max                 : 49.65
# Standard Deviation  : 11.70
# CV %                : 76.10%
# Skew                : 0.89
# Kurtosis            : -0.09
# Text Box Plot       : |0.51 --||5.92 ~ 12.09 ~ 22.45||-- 49.65|
#
# Tax 5% was not able to be profiled due to errors
#
#
# ========== Total ==========
# Column Name         : Total
# Data Type Grouping  : numeric
# Data Type           : float64
# Row Count           : 1000
# Distinct Count      : 990
# Missing Values      : 0
# Missing Value %     : 0.00%
# Mean                : 322.97
# Median              : 253.85
# Min                 : 10.68
# Max                 : 1042.65
# Standard Deviation  : 245.76
# CV %                : 76.10%
# Skew                : 0.89
# Kurtosis            : -0.09
# Text Box Plot       : |10.68 --||124.42 ~ 253.85 ~ 471.35||-- 1042.65|
#
# Total was not able to be profiled due to errors
#
#
# ========== Date ==========
# Column Name         : Date
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 89
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# Date was not able to be profiled due to errors
#
#
# ========== Time ==========
# Column Name         : Time
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 506
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# Time was not able to be profiled due to errors
#
#
# ========== Payment ==========
# Column Name         : Payment
# Data Type Grouping  : string
# Data Type           : object
# Row Count           : 1000
# Distinct Count      : 3
# Missing Values      : 0
# Missing Value %     : 0.00%
#
# Payment was not able to be profiled due to errors
#
#
# ========== cogs ==========
# Column Name         : cogs
# Data Type Grouping  : numeric
# Data Type           : float64
# Row Count           : 1000
# Distinct Count      : 990
# Missing Values      : 0
# Missing Value %     : 0.00%
# Mean                : 307.59
# Median              : 241.76
# Min                 : 10.17
# Max                 : 993.00
# Standard Deviation  : 234.06
# CV %                : 76.10%
# Skew                : 0.89
# Kurtosis            : -0.09
# Text Box Plot       : |10.17 --||118.50 ~ 241.76 ~ 448.91||-- 993.00|
#
# cogs was not able to be profiled due to errors
#
#
# ========== gross margin percentage ==========
# Column Name         : gross margin percentage
# Data Type Grouping  : numeric-condensed
# Data Type           : float64
# Row Count           : 1000
# Distinct Count      : 1
# Missing Values      : 0
# Missing Value %     : 0.00%
# Mean                : 4.76
# Median              : 4.76
# Min                 : 4.76
# Max                 : 4.76
# Standard Deviation  : 0.00
# CV %                : 0.00%
# Skew                : 0.00
# Kurtosis            : -3.00
# Text Box Plot       : |4.76 --||4.76 ~ 4.76 ~ 4.76||-- 4.76|
#
# gross margin percentage was not able to be profiled due to errors
#
#
# ========== gross income ==========
# Column Name         : gross income
# Data Type Grouping  : numeric
# Data Type           : float64
# Row Count           : 1000
# Distinct Count      : 990
# Missing Values      : 0
# Missing Value %     : 0.00%
# Mean                : 15.38
# Median              : 12.09
# Min                 : 0.51
# Max                 : 49.65
# Standard Deviation  : 11.70
# CV %                : 76.10%
# Skew                : 0.89
# Kurtosis            : -0.09
# Text Box Plot       : |0.51 --||5.92 ~ 12.09 ~ 22.45||-- 49.65|
#
# gross income was not able to be profiled due to errors
#
#
# ========== Rating ==========
# Column Name         : Rating
# Data Type Grouping  : numeric
# Data Type           : float64
# Row Count           : 1000
# Distinct Count      : 61
# Missing Values      : 0
# Missing Value %     : 0.00%
# Mean                : 6.97
# Median              : 7.00
# Min                 : 4.00
# Max                 : 10.00
# Standard Deviation  : 1.72
# CV %                : 24.63%
# Skew                : 0.01
# Kurtosis            : -1.15
# Text Box Plot       : |4.00 --||5.50 ~ 7.00 ~ 8.50||-- 10.00|
#
# Rating was not able to be profiled due to errors
#
#
# ========== Column Relationships ==========
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-72e16d97380b> in <module>()
# ----> 1 eda.auto_eda(df)
#
# /usr/local/lib/python3.7/dist-packages/edatk/_auto_eda.py in auto_eda(df, column_list, target_column, target_low_cardinality_visuals, save_path, ignore_errors, show_chart)
#      47     # Run multi column
#      48     df2.head()
# ---> 49     _auto_eda_mutli_variable(df=df2, column_list=column_list, target_column=target_column, html_report=html_report, ignore_errors=ignore_errors, show_chart=show_chart)
#      50
#      51     # Save off final html template
#
# /usr/local/lib/python3.7/dist-packages/edatk/_multi_variable/_auto_eda_multi_variable.py in _auto_eda_mutli_variable(df, column_list, target_column, html_report, ignore_errors, show_chart)
#      67
#      68     # Run all pair chart functions
# ---> 69     core._bind_to_console_html(section='multi_variable', run_type='charts', run_dict=_relationship_ops, html_report=html_report, show_chart=show_chart, header_text="Column Relationships", df=df)
#      70
#      71     # Run heatmap
#
# /usr/local/lib/python3.7/dist-packages/edatk/_core.py in _bind_to_console_html(section, run_type, run_dict, html_report, show_chart, header_text, **kwargs)
#     196
#     197             # Plot chart
# --> 198             visual(**kwargs, ax=ax)
#     199
#     200     elif run_type == 'chartx':
#
# /usr/local/lib/python3.7/dist-packages/edatk/_multi_variable/_auto_eda_multi_variable.py in inner_func(df, ax)
#      48     """
#      49     def inner_func(df, ax):
# ---> 50         return arg_func(df=df, ax=ax, **kwargs)
#      51     return inner_func
#      52
#
# /usr/local/lib/python3.7/dist-packages/edatk/_multi_variable/_visuals.py in _plot_relationship(df, column_name_one, column_name_two, ax, target_column)
#     147
#     148         # Plot distributions with barplot (target) or countplot (default)
# --> 149         df2['combinations'] = df2[column_name_one] + '\n' + df2[column_name_two]
#     150         sort_order = df2['combinations'].value_counts().reset_index()['index'].values.tolist()
#     151         cpalette = ['red' if 'Missing' in x else 'tab:blue' if 'Other' in x else 'grey' for x in sort_order]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      63                     break
#      64                 if isinstance(other, cls):
# ---> 65                     return NotImplemented
#      66
#      67         other = item_from_zerodim(other)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     341
#     342
# --> 343 def frame_arith_method_with_reindex(left: DataFrame, right: DataFrame, op) -> DataFrame:
#     344     """
#     345     For DataFrame-with-DataFrame operations that require reindexing,
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     188
#     189     Note: the caller is responsible for ensuring that numpy warnings are
# --> 190     suppressed (with np.errstate(all="ignore")) if needed.
#     191
#     192     Parameters
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     138 def _na_arithmetic_op(left, right, op, is_cmp: bool = False):
#     139     """
# --> 140     Return the result of evaluating op on the passed in values.
#     141
#     142     If native types are not compatible, try coercion to object dtype.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in <module>()
#      17 from pandas._typing import FuncType
#      18
# ---> 19 from pandas.core.computation.check import NUMEXPR_INSTALLED
#      20 from pandas.core.ops import roperator
#      21
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/check.py in <module>()
#       1 from pandas.compat._optional import import_optional_dependency
#       2
# ----> 3 ne = import_optional_dependency("numexpr", errors="warn")
#       4 NUMEXPR_INSTALLED = ne is not None
#       5 if NUMEXPR_INSTALLED:
#
# TypeError: import_optional_dependency() got an unexpected keyword argument 'errors'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2092         ratio : float
#    2093             The ratio of logical to physical pixels used for the canvas.
# -> 2094
#    2095         Returns
#    2096         -------
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in _get_renderer(figure, print_method)
#    1558     figure.draw_without_rendering()
#    1559
# -> 1560
#    1561 def _is_non_interactive_terminal_ipython(ip):
#    1562     """
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     503             Metadata in the PNG file as key-value pairs of bytes or latin-1
#     504             encodable strings.
# --> 505             According to the PNG specification, keys must be shorter than 79
#     506             chars.
#     507
#
# ImportError: cannot import name '_png' from 'matplotlib' (/usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py)
