# %%
# !pip install lxml html5lib beautifulsoup4

# %%
import pandas as pd

url = 'url de la pagina'
dfs = pd.read_html(url)

print(len(dfs))
# Out:
# 1

# %%
print(dfs[0])
# Out:
#                                               Version  ...                              End of security fixes
# 0                                                 NaN  ...                                   1993-07-29[a][2]
# 1                                                 NaN  ...                                   1994-02-15[a][2]
# 2                                                 NaN  ...                                   1994-11-10[a][2]
# 3                                                 NaN  ...                                        Unsupported
# 4                                                 NaN  ...                                        Unsupported
# 5                                                 NaN  ...                                        Unsupported
# 6                                                 NaN  ...                                   1999-04-13[a][2]
# ...

# %%
print(dfs[0]['nombre de la columna 1'])
print(dfs[0]['nombre de la columna 2'])
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
import pandas as pd

# Webpage url                                                                                                               
url = 'url de la pagina'

# Extract tables
dfs = pd.read_html(url)

# Get first table                                                                                                           
df = dfs[0]

# Extract columns                                                                                                           
df2 = df[['nombre de la columna','nombre de la columna']]
print(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-96ac8c1f343a> in <module>()
#       5
#       6 # Extract tables
# ----> 7 dfs = pd.read_html(url)
#       8
#       9 # Get first table
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
#    1100         keep_default_na=keep_default_na,
# -> 1101         displayed_only=displayed_only,
#    1102     )
#
# ...

# %%
df2.to_excel('___.xlsx')

# %%
df = pd.read_excel('___.xlsx')

# %%
df
# Out:
#     Unnamed: 0  ...                                       Release date
# 0            0  ...                                      1991-02-20[2]
# 1            1  ...                                      1994-01-26[2]
# 2            2  ...                                      1994-10-11[2]
# 3            3  ...                                      1995-04-13[2]
# 4            4  ...                                      1995-10-13[2]
# 5            5  ...                                      1996-10-25[2]
# 6            6  ...                                      1998-01-03[2]
# 7            7  ...                                     2000-09-05[41]
# 8            8  ...                                     2000-10-16[43]
# 9            9  ...                                     2001-04-15[44]
# 10          10  ...                                     2001-12-21[45]
# 11          11  ...                                     2003-06-29[46]
# ...
